# %% [markdown]
# <a href="https://colab.research.google.com/github/Aromie/acaformula/blob/master/financialDiary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

financialDiary = [['income1',80,'11-01'],['income2',30,'11-06'],['samca',-83,'11-06'],['socks',-2.4,'11-07']]
fD=pd.DataFrame(financialDiary, columns=['category','amount','date'])
#df = pd.DataFrame(data, columns=['name', 'English', 'math'])
fD
# Out:
#   category  amount   date
# 0  income1    80.0  11-01
# 1  income2    30.0  11-06
# 2    samca   -83.0  11-06
# 3    socks    -2.4  11-07

# %%
# Calculate the balance based on the "amount" column
fD['balance'] = fD['amount'].cumsum()
fD
# Out:
#   category  amount   date    memo  balance
# 0  income1    80.0  11-01  purnet     80.0
# 1  income2    30.0  11-06     son    110.0
# 2    samca   -83.0  11-06     NaN     27.0
# 3    socks    -2.4  11-07     NaN     24.6
# 4    snack    -0.5  11-08     NaN     24.1

# %%
import numpy as np
fD['memo']=np.nan

# %%
fD
# Out:
#   category  amount   date  balance  memo
# 0  income1    80.0  11-01     80.0   NaN
# 1  income2    30.0  11-06    110.0   NaN
# 2    samca   -83.0  11-06     27.0   NaN
# 3    socks    -2.4  11-07     24.6   NaN

# %%
fD.loc[0,'memo']='purnet'

# %%
fD
# Out:
#   category  amount   date  balance    memo
# 0  income1    80.0  11-01     80.0  purnet
# 1  income2    30.0  11-06    110.0     NaN
# 2    samca   -83.0  11-06     27.0     NaN
# 3    socks    -2.4  11-07     24.6     NaN

# %%
#df.loc[df['Column_Name'] == value_to_replace, 'Column_Name'] = new_value
fD.loc[1, 'memo']="son"
fD
# Out:
#   category  amount   date    memo
# 0  income1    80.0  11-01  purnet
# 1  income2    30.0  11-06     son
# 2    samca   -83.0  11-06     NaN
# 3    socks    -2.4  11-07     NaN

# %%
'''
new_row = {'Column1': value7, 'Column2': value8}
df = df.append(new_row, ignore_index=True)
'''
new_outcome={'category':'tea','amount':-2.4,'date':'11-07'}
fD=fD.append(new_outcome, ignore_index=True)
fD
# Out:
# <ipython-input-20-a828e618ea1c>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fD=fD.append(new_outcome, ignore_index=True)
#   category  amount   date  balance    memo
# 0  income1    80.0  11-01     80.0  purnet
# 1  income2    30.0  11-06    110.0     son
# 2    samca   -83.0  11-06     27.0     NaN
# 3    socks    -2.4  11-07     24.6     NaN
# 4      tea    -2.4  11-07      NaN     NaN

# %%
'''
# Create a new row as a DataFrame
new_row = pd.DataFrame({'Column1': [4], 'Column2': ['D']})

# Concatenate the existing DataFrame with the new row
df = pd.concat([df, new_row], ignore_index=True)
'''
new_row=pd.DataFrame({'category':['snack'],'amount':[-0.5],'date':['11-08']})
fD=pd.concat([fD, new_row], ignore_index=True)
fD
# Out:
#   category  amount   date    memo
# 0  income1    80.0  11-01  purnet
# 1  income2    30.0  11-06     son
# 2    samca   -83.0  11-06     NaN
# 3    socks    -2.4  11-07     NaN
# 4    snack    -0.5  11-08     NaN

# %%
'''
# Specify the desired order of columns
desired_order = ['C', 'A', 'B']

# Create a new DataFrame with columns in the desired order
df_reordered = df[desired_order]
category	amount	date	balance	memo
'''
new_order=['category','amount','date','balance','memo']
fD_recordered = fD[new_order]

# %%
fD
# Out:
#   category  amount   date    memo  balance
# 0  income1    80.0  11-01  purnet     80.0
# 1  income2    30.0  11-06     son    110.0
# 2    samca   -83.0  11-06     NaN     27.0
# 3    socks    -2.4  11-07     NaN     24.6
# 4    snack    -0.5  11-08     NaN     24.1

# %%
#df = df.reorder_levels(['C', 'A', 'B'], axis=1)
fD=fD.reorder_levels(['category',	'amount',	'date',	'balance',	'memo'], axis=1)
fD
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-61eb29a0c0c6> in <cell line: 2>()
#       1 #df = df.reorder_levels(['C', 'A', 'B'], axis=1)
# ----> 2 fD=fD.reorder_levels(['category',       'amount',       'date', 'balance',      'memo'], axis=1)
#       3 fD
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in reorder_levels(self, order, axis)
#    7559         axis = self._get_axis_number(axis)
#    7560         if not isinstance(self._get_axis(axis), MultiIndex):  # pragma: no cover
# -> 7561             raise TypeError("Can only reorder levels on a hierarchical axis.")
#    7562
#    7563         result = self.copy()
#
# TypeError: Can only reorder levels on a hierarchical axis.

# %%
#df = df.reindex(columns=desired_order)
fD=fD.reindex(columns=new_order)
fD
# Out:
#   category  amount   date  balance    memo
# 0  income1    80.0  11-01     80.0  purnet
# 1  income2    30.0  11-06    110.0     son
# 2    samca   -83.0  11-06     27.0     NaN
# 3    socks    -2.4  11-07     24.6     NaN
# 4    snack    -0.5  11-08     24.1     NaN

# %%
fD.to_csv("financial.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

# Use the file upload widget
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6e76d379-e2b5-4ca3-bf5c-96248d887926" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e76d379-e2b5-4ca3-bf5c-96248d887926">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import shutil

# Specify the paths
uploaded_file_path = 'financial.csv'
drive_folder_path = '/content/drive/MyDrive/Colab Notebooks'

# Move the file to Google Drive
shutil.move(uploaded_file_path, drive_folder_path)
